# %%
# !gpustat
# Out:
# cudahpc08  Tue Jun  4 16:14:18 2019
# [0] GeForce GTX 1080 Ti | 51'C,  49 % |   854 / 11178 MB | carles(425M) carles(419M)
# [1] GeForce GTX 1080 Ti | 24'C,   0 % |    10 / 11178 MB |
# [2] GeForce GTX 1080 Ti | 23'C,   0 % |    10 / 11178 MB |
# [3] GeForce GTX 1080 Ti | 25'C,   0 % |    10 / 11178 MB |
# [4] GeForce GTX 1080 Ti | 24'C,   0 % |    10 / 11178 MB |
# [5] GeForce GTX 1080 Ti | 24'C,   0 % |    10 / 11178 MB |
# [6] GeForce GTX 1080 Ti | 23'C,   0 % |    10 / 11178 MB |

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
from sep_cons_experiment import SepConsExperiment
from keras import regularizers
from sklearn.model_selection import ParameterGrid
from tqdm import tqdm
import numpy as np

# %%
widths = list(range(1,5)) + list(range(5,26, 5))
depths = list(range(120,151, 10))

print(widths)
print(depths)
# Out:
# [1, 2, 3, 4, 5, 10, 15, 20, 25]
# [120, 130, 140, 150]

# %%
epochs = 5000

param_grid = ParameterGrid({'activation': ['relu_bn'], 'lr': [0.01], 'batch_size': [85,],
                           'depth': depths, 'width': widths,
                           })

for params in tqdm(param_grid):
    activation, lr, batch_size = params['activation'], params['lr'], params['batch_size']
    depth, width = params['depth'], params['width']
    summary_path = 'moons_grid_summaries'
    name = f'moons-grid-{activation}'
    print(name)
    exp = SepConsExperiment()
    exp.run(name=name, dataset='moons', epochs=epochs,
            optimizer='adam', lr=lr, batch_size=batch_size,
            depth=depth, width=width, activation=activation,  seed=10,
            kernel_size=None,
            memory=0.25,
            layer_parameters={
                'padding': 'same',                
                'use_bias': True,
            },
            log_dir=summary_path
            )
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# moons-grid-relu_bn
# {'self': <toy.Toy object at 0x7f75ec0f9748>, 'name': 'moons-grid-relu_bn', 'dataset': 'moons', 'lr': 0.01, 'batch_size': 85, 'epochs': 5000, 'optimizer': 'adam', 'histogram_freq': 0, 'write_grads': False, 'loss': 'crossentropy', 'epoch_start': 0, 'epoch_freq': 0, 'show_on_train': False, 'seed': 10, 'show_input_layer': False, 'show_local_layers': False, 'show_decision_layers': True, 'batch_freq': 0, 'check_weights': False, 'check_gradients': False, 'check_units': None, 'check_optimizer': False, 'write_graph': False, 'check_numerics': False, 'verbose': 0, 'memory': 0.25, 'write_images': False, 'embeddings_freq': None, 'embeddings_layer_names': None, 'extra': None, 'save_config': True, 'store_img': False, 'lr_schedule': None, 'min_lr': 1e-05, 'max_lr': 0.01, 'min_mtm': 0.85, 'max_mtm': 0.95, 'step_size': 1000, 'plot_matrix': False, 'plot_activations': False, 'plot_all_losses': False, 'log_dir': 'moons_grid_summaries', 'cached': False, 'plot_surface': False, 'single_plot': False, 'annealing_dropout_epochs': None, 'annealing_dropout_rate': 0.5, 'print_weights': False, 'kwargs': {'depth': 120, 'width': 1, 'activation': 'relu_bn', 'kernel_size': None, 'layer_parameters': {'padding': 'same', 'use_bias': True}}}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# WARNING:tensorflow:From /home/carles/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# WARNING:tensorflow:From /home/carles/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#   3%|▎         | 1/36 [12:42<7:25:04, 762.99s/it]
# moons-grid-relu_bn
# {'self': <toy.Toy object at 0x7f74724b3da0>, 'name': 'moons-grid-relu_bn', 'dataset': 'moons', 'lr': 0.01, 'batch_size': 85, 'epochs': 5000, 'optimizer': 'adam', 'histogram_freq': 0, 'write_grads': False, 'loss': 'crossentropy', 'epoch_start': 0, 'epoch_freq': 0, 'show_on_train': False, 'seed': 10, 'show_input_layer': False, 'show_local_layers': False, 'show_decision_layers': True, 'batch_freq': 0, 'check_weights': False, 'check_gradients': False, 'check_units': None, 'check_optimizer': False, 'write_graph': False, 'check_numerics': False, 'verbose': 0, 'memory': 0.25, 'write_images': False, 'embeddings_freq': None, 'embeddings_layer_names': None, 'extra': None, 'save_config': True, 'store_img': False, 'lr_schedule': None, 'min_lr': 1e-05, 'max_lr': 0.01, 'min_mtm': 0.85, 'max_mtm': 0.95, 'step_size': 1000, 'plot_matrix': False, 'plot_activations': False, 'plot_all_losses': False, 'log_dir': 'moons_grid_summaries', 'cached': False, 'plot_surface': False, 'single_plot': False, 'annealing_dropout_epochs': None, 'annealing_dropout_rate': 0.5, 'print_weights': False, 'kwargs': {'depth': 120, 'width': 2, 'activation': 'relu_bn', 'kernel_size': None, 'layer_parameters': {'padding': 'same', 'use_bias': True}}}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
#   6%|▌         | 2/36 [26:23<7:22:05, 780.15s/it]
# moons-grid-relu_bn
# {'self': <toy.Toy object at 0x7f74405d0668>, 'name': 'moons-grid-relu_bn', 'dataset': 'moons', 'lr': 0.01, 'batch_size': 85, 'epochs': 5000, 'optimizer': 'adam', 'histogram_freq': 0, 'write_grads': False, 'loss': 'crossentropy', 'epoch_start': 0, 'epoch_freq': 0, 'show_on_train': False, 'seed': 10, 'show_input_layer': False, 'show_local_layers': False, 'show_decision_layers': True, 'batch_freq': 0, 'check_weights': False, 'check_gradients': False, 'check_units': None, 'check_optimizer': False, 'write_graph': False, 'check_numerics': False, 'verbose': 0, 'memory': 0.25, 'write_images': False, 'embeddings_freq': None, 'embeddings_layer_names': None, 'extra': None, 'save_config': True, 'store_img': False, 'lr_schedule': None, 'min_lr': 1e-05, 'max_lr': 0.01, 'min_mtm': 0.85, 'max_mtm': 0.95, 'step_size': 1000, 'plot_matrix': False, 'plot_activations': False, 'plot_all_losses': False, 'log_dir': 'moons_grid_summaries', 'cached': False, 'plot_surface': False, 'single_plot': False, 'annealing_dropout_epochs': None, 'annealing_dropout_rate': 0.5, 'print_weights': False, 'kwargs': {'depth': 120, 'width': 3, 'activation': 'relu_bn', 'kernel_size': None, 'layer_parameters': {'padding': 'same', 'use_bias': True}}}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
#   8%|▊         | 3/36 [40:48<7:23:04, 805.60s/it]
# moons-grid-relu_bn
# {'self': <toy.Toy object at 0x7f741d76edd8>, 'name': 'moons-grid-relu_bn', 'dataset': 'moons', 'lr': 0.01, 'batch_size': 85, 'epochs': 5000, 'optimizer': 'adam', 'histogram_freq': 0, 'write_grads': False, 'loss': 'crossentropy', 'epoch_start': 0, 'epoch_freq': 0, 'show_on_train': False, 'seed': 10, 'show_input_layer': False, 'show_local_layers': False, 'show_decision_layers': True, 'batch_freq': 0, 'check_weights': False, 'check_gradients': False, 'check_units': None, 'check_optimizer': False, 'write_graph': False, 'check_numerics': False, 'verbose': 0, 'memory': 0.25, 'write_images': False, 'embeddings_freq': None, 'embeddings_layer_names': None, 'extra': None, 'save_config': True, 'store_img': False, 'lr_schedule': None, 'min_lr': 1e-05, 'max_lr': 0.01, 'min_mtm': 0.85, 'max_mtm': 0.95, 'step_size': 1000, 'plot_matrix': False, 'plot_activations': False, 'plot_all_losses': False, 'log_dir': 'moons_grid_summaries', 'cached': False, 'plot_surface': False, 'single_plot': False, 'annealing_dropout_epochs': None, 'annealing_dropout_rate': 0.5, 'print_weights': False, 'kwargs': {'depth': 120, 'width': 4, 'activation': 'relu_bn', 'kernel_size': None, 'layer_parameters': {'padding': 'same', 'use_bias': True}}}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
#  11%|█         | 4/36 [56:35<7:32:20, 848.14s/it]
# moons-grid-relu_bn
# {'self': <toy.Toy object at 0x7f741347dc18>, 'name': 'moons-grid-relu_bn', 'dataset': 'moons', 'lr': 0.01, 'batch_size': 85, 'epochs': 5000, 'optimizer': 'adam', 'histogram_freq': 0, 'write_grads': False, 'loss': 'crossentropy', 'epoch_start': 0, 'epoch_freq': 0, 'show_on_train': False, 'seed': 10, 'show_input_layer': False, 'show_local_layers': False, 'show_decision_layers': True, 'batch_freq': 0, 'check_weights': False, 'check_gradients': False, 'check_units': None, 'check_optimizer': False, 'write_graph': False, 'check_numerics': False, 'verbose': 0, 'memory': 0.25, 'write_images': False, 'embeddings_freq': None, 'embeddings_layer_names': None, 'extra': None, 'save_config': True, 'store_img': False, 'lr_schedule': None, 'min_lr': 1e-05, 'max_lr': 0.01, 'min_mtm': 0.85, 'max_mtm': 0.95, 'step_size': 1000, 'plot_matrix': False, 'plot_activations': False, 'plot_all_losses': False, 'log_dir': 'moons_grid_summaries', 'cached': False, 'plot_surface': False, 'single_plot': False, 'annealing_dropout_epochs': None, 'annealing_dropout_rate': 0.5, 'print_weights': False, 'kwargs': {'depth': 120, 'width': 5, 'activation': 'relu_bn', 'kernel_size': None, 'layer_parameters': {'padding': 'same', 'use_bias': True}}}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
# {'padding': 'same', 'use_bias': True, 'activation': None}
